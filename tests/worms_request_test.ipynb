# %%
# imports
import requests
import time
import pandas as pd
import json

# %%
# read csv 
df_observations = pd.read_csv("../files/tidy/inat_observations.csv")

# no need for repeated names, use unique() to get distinct values.
request_list = df_observations["taxon.name"].unique().tolist()
request_list.sort()
total = len(request_list)
print(f"There are {total} unique taxon names")

taxa_df = pd.DataFrame(request_list)
taxa_df.to_csv('../files/tidy/inat_request_list.csv', index = False, header = False)
# Out:
# There are 257 unique taxon names

# %%
# WoRMS API URLs
base_url = "https://www.marinespecies.org/rest"
aphia_record_endpoint = "/AphiaRecordsByName/"
classification_endpoint = "/AphiaClassificationByAphiaID/"

# results list to convert into pd df later
worms = []

# %%
def get_aphia_records(scientific_name):
    try:
        response = requests.get(base_url + aphia_record_endpoint + scientific_name)
        response.raise_for_status()
        return response.json()
    except Exception as e:
        print(f"Error for {scientific_name}: {e}")
        return None

# %%
# start_time = time.time()
# for i in request_list:
#     print(f"Going through {i}")
#     result = get_aphia_records(i)
#     if result:
#         accepted = [record for record in result if record.get('status') == 'accepted' and record.get('kingdom') == 'Animalia']
#         worms.extend(accepted)
# end_time = time.time()

# %%
def get_target_rank(records, target_name):
    target_name = str(target_name).lower().replace("_", " ")

    for record in records:
        scientificname = str(record.get("scientificname") or "").lower()
        status = record.get("status")
        if scientificname == target_name and status in {"accepted", "alternative representation"}:
            return record.get("rank")
    return None

# %%
start_time = time.time()
for i in request_list:
    query_name = i.replace("_", " ")
    print(f"Going through {i}")
    result = get_aphia_records(query_name)
    if result:
        # print(f"API Response for {i}:")
        # print(json.dumps(result, indent=2))
        target_rank = get_target_rank(result, i)
        if target_rank:
            filtered_records = [
                record for record in result
                if record.get("status") in {"accepted", "alternative representation"}
                and record.get("rank") == target_rank
                and str(record.get("scientificname") or "").lower().replace(" ", "_") == i.lower() 
            ]
            worms.extend(filtered_records)  
end_time = time.time()
# Out:
# Going through Abudefduf_troschelii
# Going through Acanthurus_coeruleus
# Going through Acanthurus_nigricans
# Going through Acanthurus_xanthopterus
# Going through Acropora_palmata
# Going through Actiniaria
# Going through Aetobatus_laticeps
# Going through Agaricia_tenuifolia
# Going through Ammotheidae
# Going through Amphiodia_occidentalis
# Going through Anemonia_viridis
# Going through Aniculus_elegans
# Going through Anisotremus_davidsonii
# Going through Anisotremus_taeniatus
# Going through Anisotremus_virginicus
# Going through Antennariidae
# Going through Anthopleura_elegantissima
# Going through Anthopleura_sola
# Going through Anthopleura_xanthogrammica
# Going through Anthozoa
# Going through Antillogorgia_americana
# Going through Aplysia
# Going through Aplysia_californica
# Going through Aplysia_dactylomela
# Going through Aplysia_punctata
# Going through Aplysia_vaccaria
# Going through Aplysina_gerardogreeni
# Going through Apostichopus_californicus
# Going through Arachnactidae
# Going through Armina_californica
# Going through Arothron_hispidus
# Going through Arothron_meleagris
# Going through Ascidia_sideralis
# Going through Asteroidea
# Going through Astropyga_pulvinata
# Going through Azurina_atrilobata
# Going through Balanophyllia_regia
# Going through Balistes_polylepis
# Going through Bodianus_diplotaenia
# Going through Bolinopsidae
# Going through Botrylloides_niger
# Going through Bunodosoma_grande
# Going through Caenogastropoda
# Going through Canthigaster_punctatissima
# Going through Carangidae
# Going through Caranx_bartholomaei
# Going through Caranx_caballus
# Going through Caranx_caninus
# Going through Caranx_melampygus
# Going through Muraena_clepsydra
# Going through Muraena_lentiginosa
# Going through Muricea
# Going through Myriopathes_panamensis
# Going through Myripristis_berndti
# Going through Mytilus_californianus
# Going through Naticidae
# Going through Neaxius
# Going through Neobernaya_spadicea
# Going through Nidorellia_armata
# Going through Nuttallina
# Going through Octopoda
# Going through Octopus
# Going through Octopus_bimaculatus
# Going through Ophioblennius_steindachneri
# Going through Ophiuroidea
# Going through Opsanus_beta
# Going through Ostreida
# Going through Oxycirrhites_typus
# Going through Pacifigorgia
# Going through Palythoa_caribaeorum
# Going through Parablennius_parvicornis
# Going through Paracentrotus_lividus
# Going through Paralabrax_clathratus
# Going through Parapsettus_panamensis
# Going through Pareques_acuminatus
# Going through Patiria_miniata
# Going through Pavona
# Going through Pavona_gigantea
# Going through Pennaria
# Going through Pennaria_disticha
# Going through Pentaceraster_cumingi
# Going through Pharia_pyramidata
# Going through Phataria_unifascialis
# Going through Physalia_physalis
# Going through Pinctada_mazatlanica
# Going through Placospongia
# Going through Plagusia_depressa
# Going through Pleurobranchus_areolatus
# Going through Plexauridae
# Going through Pocillopora
# Going through Pollicipes_polymerus
# Going through Pomacanthus_zonipectus
# Going through Porifera
# Going through Porites
# Going through Pseudobalistes_naufragium
# Going through Pseudocnus_californicus
# Going through Pseudodiploria_clivosa
# Going through Pterogorgia
# Going through Pterois_volitans
# Going through Pycnogonida
# Going through Pyrosoma
# Going through Pyrosomatida
# Going through Rhopalaea_birkelandi
# Going through Rypticus_bicolor
# Going through Sabellastarte
# Going through Sabellidae
# Going through Scarus_ghobban
# Going through Scarus_rubroviolaceus
# Going through Scorpaena_mystes
# Going through Serpulidae
# Going through Serranus_psittacinus
# Going through Siderastrea_radians
# Going through Siderastrea_siderea
# Going through Similiparma_lurida
# Going through Spondylus
# Going through Stegastes
# Going through Stegastes_acapulcoensis
# Going through Stegastes_flavilatus
# Going through Stellamedusa_ventana
# Going through Stenoplax
# Going through Stenoplax_conspicua
# Going through Stenorhynchus_debilis
# Going through Stichodactyla_helianthus
# Going through Stomatopoda
# Going through Strongylocentrotus
# Going through Strongylocentrotus_purpuratus
# Going through Styracura_pacifica
# Going through Sufflamen_verres
# Going through Synodontidae
# Going through Telmatactis
# Going through Terebellidae
# Going through Thalassoma_bifasciatum
# Going through Thalassoma_lucasanum
# Going through Thalassoma_pavo
# Going through Tonicia_forbesii
# Going through Toxopneustes_roseus
# Going through Toxopneustidae
# Going through Triaenodon_obesus
# Going through Triopha_maculata
# Going through Tripneustes_depressus
# Going through Tripneustes_ventricosus
# Going through Tubastraea_coccinea
# Going through Urobatis_pardalis
# Going through Urticina
# Going through Urticina_eques
# Going through Xenichthys_xanti
# Going through Zanclus_cornutus

# %%
# benchmark
duration = end_time - start_time 
min = int(duration // 60)
s = int(duration % 60)
print(f"This lasted {min}:{s:02d} minutes")
# Lasted 4:09 minutes for 256 taxa without filtering
# Duration depends on internet connection

# After adding the status = accepted, it lasted 3:33 minutes
# Still have to check if there were any changes

# After adding status = accepted and kingdom = Animalia, it lasted 3:15 minutes
# Out:
# This lasted 3:26 minutes

# %%
worms = pd.DataFrame(worms)

# %%
worms.to_csv('../files/tidy/worms_output_test.csv', index=False)
